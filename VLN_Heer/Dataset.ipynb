# %%
# !pip install huggingface_hub

# %%
# pip install --upgrade pip

# %%
# pip install datasets

# %%
# !export HF_HOME="/projectnb/cs598/projects/VLN_MMML/canvas dataset"
import os

os.environ["HF_HOME"] = "/projectnb/cs598/projects/VLN_MMML/canvas_dataset"

# %%
from datasets import load_dataset

# %%
datasetn = "maum-ai/COMMAND"

dataset = load_dataset(datasetn)
# Print dataset location
print(f"Dataset saved at: {dataset.cache_files}")
# Out:
# README.md:   0%|          | 0.00/6.74k [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/3325 [00:00<?, ?it/s]
# ...
# (…)%2F001cd87d182d287bee7a888116b8cf56.json:   0%|          | 0.00/909 [00:00<?, ?B/s]
# (…)%2F0156583da8ce154b35ba81727240b211.json:   0%|          | 0.00/708 [00:00<?, ?B/s]
# (…)%2F013d909d5ac710266985ab5b08b65f5f.json:   0%|          | 0.00/708 [00:00<?, ?B/s]
# (…)%2F00ba0d2735dfe77bc2d55dd13e2fffd2.json:   0%|          | 0.00/710 [00:00<?, ?B/s]
# (…)%2F004c1a58b132576b57c0a1635ea2da25.json:   0%|          | 0.00/713 [00:00<?, ?B/s]
# (…)%2F0179230c756d78a2cfbbdc89f122ce61.json:   0%|          | 0.00/710 [00:00<?, ?B/s]
# (…)%2F0164dc1aff4e411fa28833164cd7d3e5.json:   0%|          | 0.00/708 [00:00<?, ?B/s]
# (…)%2F000f0d07bb3c04d41aa16e90c099619b.json:   0%|          | 0.00/712 [00:00<?, ?B/s]
# (…)%2F00289a2e3f7cb86f3a708a38b68f1926.json:   0%|          | 0.00/711 [00:00<?, ?B/s]
# ...

# %%
import pandas as pd

# %%
df = dataset["train"].to_pandas()

# %%
print(df.head())
# Out:
#                                        semantic_uuid         map_name  \
# 0         sim_office/coffee_delivery/misleading/12/3       sim_office
# 1           sim_office/coffee_delivery/precise/14/64       sim_office
# 2  sim_street_road/right_food_delivery/misleading...  sim_street_road
# 3         sim_office/coffee_delivery/misleading/8/30       sim_office
# 4             sim_office/coffee_delivery/precise/2/6       sim_office
#
#            sketch_map_name     start end drive_map_name  \
# 0  annotated_occupancy_map  (random)  13  occupancy_map
# 1  annotated_occupancy_map  (random)  15  occupancy_map
# 2         orthographic_map  (random)  15  occupancy_map
# 3  annotated_occupancy_map  (random)   9  occupancy_map
# 4  annotated_occupancy_map  (random)   3  occupancy_map
#
#                                      model_guideline
# 0  You are an indoor food-serving robot.\n\nYou m...
# 1  You are an indoor food-serving robot.\n\nYou m...
# ...

# %%
print(df.columns)
# Out:
# Index(['semantic_uuid', 'map_name', 'sketch_map_name', 'start', 'end',
#        'drive_map_name', 'model_guideline'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3317 entries, 0 to 3316
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   semantic_uuid    3317 non-null   object
#  1   map_name         3317 non-null   object
#  2   sketch_map_name  3317 non-null   object
#  3   start            3317 non-null   object
#  4   end              3317 non-null   object
#  5   drive_map_name   3317 non-null   object
#  6   model_guideline  3317 non-null   object
# dtypes: object(7)
# memory usage: 181.5+ KB
# None

# %%
print(df["model_guideline"].info())
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3317 entries, 0 to 3316
# Series name: model_guideline
# Non-Null Count  Dtype
# --------------  -----
# 3317 non-null   object
# dtypes: object(1)
# memory usage: 26.0+ KB
# None

# %%
print(df["model_guideline"].unique())
# Out:
# ['You are an indoor food-serving robot.\n\nYou must follow these driving instructions:\n1. You must avoid collisions.\n2. You should prioritize reaching the final destination.\n3. You should follow the Trajectory Instruction.\n    a. If the Trajectory Instruction cannot be followed due to any obstacles, you should deviate to bypass the obstacle.\n    b. You should try to evade any identifiable obstacles.\n4. You should maintain a constant driving speed.'
# ...

# %%
column_values = df["model_guideline"].tolist()

# %%
print(column_values)
# Out:
# ['You are an indoor food-serving robot.\n\nYou must follow these driving instructions:\n1. You must avoid collisions.\n2. You should prioritize reaching the final destination.\n3. You should follow the Trajectory Instruction.\n    a. If the Trajectory Instruction cannot be followed due to any obstacles, you should deviate to bypass the obstacle.\n    b. You should try to evade any identifiable obstacles.\n4. You should maintain a constant driving speed.', 'You are an indoor food-serving robot.\n\nYou must follow these driving instructions:\n1. You must avoid collisions.\n2. You should prioritize reaching the final destination.\n3. You should follow the Trajectory Instruction.\n    a. If the Trajectory Instruction cannot be followed due to any obstacles, you should deviate to bypass the obstacle.\n    b. You should try to evade any identifiable obstacles.\n4. You should maintain a constant driving speed.', 'You are an outdoor self-driving robot taxi.\n\nYou must follow these driving i
# ...

# %%
# df = dataset["test"].to_pandas()
